# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %%
weaponData = pd.read_csv('weapon.csv')
weaponData.head()
# Out:
#        |                        name  quality                        icon  \
# 0   6975               Whirlwind Axe        3                  inv_axe_12
# 1   6687                 Corpsemaker        3       inv_weapon_halbard_01
# 2  17182  Sulfuras, Hand of Ragnaros        5  inv_hammer_unique_sulfuras
# 3   6953              Verigan's Fist        3               inv_hammer_05
# 4   7717                     Ravager        3       inv_weapon_halberd_05
#
#    screenshot  arcsplpwr  arcres  buyprice  armor  def  ...   spi  \
# 0      242600        NaN     NaN       NaN    NaN  NaN  ...   NaN
# 1       64899        NaN     NaN       NaN    NaN  NaN  ...   NaN
# 2      330071        NaN     NaN       NaN    NaN  NaN  ...   NaN
# 3      151895        NaN     NaN       NaN    NaN  NaN  ...  12.0
# 4       82029        NaN     NaN       NaN    NaN  NaN  ...   NaN
#
#    splcritstrkpct  splpen  splhitpct  splheal  splpwr   sta   str  attainable  \
# 0             NaN     NaN        NaN      NaN     NaN  14.0  15.0           0
# 1             NaN     NaN        NaN      NaN     NaN   8.0  15.0           0
# 2             NaN     NaN        NaN      NaN     NaN  12.0  12.0           0
# 3             NaN     NaN        NaN      NaN     NaN   7.0   NaN           0
# 4             NaN     NaN        NaN      NaN     NaN   NaN   NaN           0
#
#    flags2
# 0    8192
# 1    8192
# 2    8192
# 3    8192
# 4    8192
#
# [5 rows x 67 columns]

# %%
weaponAttactData
