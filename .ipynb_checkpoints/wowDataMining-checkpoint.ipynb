# %%
# Basic Libraries
# %pylab inline
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
from sklearn.linear_model import RANSACRegressor, LinearRegression
from sklearn.datasets import make_regression
sb.set() # set the default Seaborn style for graphics
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
rawData1 = pd.read_csv('weapon.csv')
rawData1.head()
rawData1.rename(columns={'|': 'unknown', '|__name_enus': 'name',  
                        '|__quality': 'quality', '|__icon': 'icon', 
                        '|__screenshot': 'screenshot', '|__jsonequip__cooldown': 'cooldown', 
                        '|__jsonequip__arcres': 'arcres', '|__jsonequip__armor': 'armor', 
                        '|__jsonequip__agi': 'agi', '|__jsonequip__atkpwr': 'atkpwr', 
                        '|__jsonequip__avgbuyout': 'avgbuyout', '|__jsonequip__buyprice': 'buyprice', 
                        '|__jsonequip__def': 'def', '|__jsonequip__classes': 'classes', 
                        '|__jsonequip__displayid': 'displayid', '|__jsonequip__dmgmax1': 'dmgmax1', 
                        '|__jsonequip__dmgmin1': 'dmgmin1', '|__jsonequip__dmgrange': 'dmgrange', 
                        '|__jsonequip__dmgtype1': 'dmgtype1', '|__jsonequip__dps': 'dps', 
                        '|__jsonequip__dura': 'dura', '|__jsonequip__manargn': 'manargn', 
                        '|__jsonequip__healthrgn': 'healthrgn', '|__jsonequip__int': 'int', 
                        '|__jsonequip__firres': 'firres', '|__jsonequip__frores': 'frores', 
                        '|__jsonequip__holsplpwr': 'holsplpwr', '|__jsonequip__maxcount': 'maxcount',
                        '|__jsonequip__mlecritstrkpct': 'mlecritstrkpct', '|__jsonequip__mledmgmax': 'mledmgmax',
                        '|__jsonequip__mledmgmin': 'mledmgmin', '|__jsonequip__mledps': 'mledps',
                        '|__jsonequip__mlehitpct': 'mlehitpct', '|__jsonequip__mlespeed': 'mlespeed',
                        '|__jsonequip__races': 'races', '|__jsonequip__reqskill': 'reqskill',
                        '|__jsonequip__reqskillrank': 'reqskillrank', '|__jsonequip__natres': 'natres',
                        '|__jsonequip__parrypct': 'parrypct', '|__jsonequip__reqlevel': 'reqlevel',
                        '|__jsonequip__rgdcritstrkpct': 'rgdcritstrkpct', '|__jsonequip__rgdhitpct': 'rgdhitpct',
                        '|__jsonequip__sellprice': 'sellprice', '|__jsonequip__shares': 'shares',
                        '|__jsonequip__sheathtype': 'sheathtype', 
                        '|__jsonequip__slotbak': 'slotbak', '|__jsonequip__speed': 'speed', 
                        '|__jsonequip__splcritstrkpct': 'splcritstrkpct', '|__jsonequip__splpwr': 'splpwr', 
                        '|__jsonequip__spi': 'spi', '|__jsonequip__splheal': 'splheal', 
                        '|__jsonequip__sta': 'sta', '|__jsonequip__str': 'str', 
                        '|__attainable': 'attainable', '|__flags2': 'flags2',
                       }, inplace=True)
rawData1.head()
# Out:
#    unknown                  name  quality                   icon  screenshot  \
# 0     6975         Whirlwind Axe        3             inv_axe_12      242600
# 1     7717               Ravager        3  inv_weapon_halberd_05       82029
# 2     3853  Moonsteel Broadsword        2           inv_sword_25       69983
# 3     6687           Corpsemaker        3  inv_weapon_halbard_01       64899
# 4    12784       Arcanite Reaper        3             inv_axe_09       89138
#
#    cooldown  arcres  armor  agi  atkpwr  avgbuyout  buyprice  def  classes  \
# 0       NaN     NaN    NaN  NaN     NaN        NaN       NaN  NaN      1.0
# 1       NaN     NaN    NaN  NaN     NaN        NaN       NaN  NaN      NaN
# 2       NaN     NaN    NaN  NaN     NaN    39800.0       NaN  NaN      NaN
# 3       NaN     NaN    NaN  NaN     NaN        NaN       NaN  NaN      NaN
# 4       NaN     NaN    NaN  NaN    62.0        NaN       NaN  NaN      NaN
#
#    displayid  dmgmax1  dmgmin1  dmgrange  dmgtype1    dps  dura  manargn  \
# 0      22734    154.0    102.0         1         0  35.56   100      NaN
# 1      22221    157.0    104.0         1         0  37.29   100      NaN
# 2       7324     83.0     55.0         1         0  24.64    85      NaN
# 3      22217    132.0     88.0         1         0  28.95   100      NaN
# 4      23904    256.0    153.0         1         0  53.82   100      NaN
#
#    healthrgn  int  firres  frores  holsplpwr  maxcount  mlecritstrkpct  \
# 0        NaN  NaN     NaN     NaN        NaN       NaN             NaN
# 1        NaN  NaN     NaN     NaN        NaN       NaN             NaN
# 2        NaN  NaN     NaN     NaN        NaN       NaN             NaN
# 3        NaN  NaN     NaN     NaN        NaN       NaN             NaN
# 4        NaN  NaN     NaN     NaN        NaN       NaN             NaN
#
#    mledmgmax  mledmgmin  mledps  mlehitpct  mlespeed  races  reqskill  \
# 0      154.0      102.0   35.56        NaN       3.6    NaN       NaN
# 1      157.0      104.0   37.29        NaN       3.5    NaN       NaN
# 2       83.0       55.0   24.64        NaN       2.8    NaN       NaN
# 3      132.0       88.0   28.95        NaN       3.8    NaN       NaN
# 4      256.0      153.0   53.82        NaN       3.8    NaN       NaN
#
#    reqskillrank  natres  parrypct  reqlevel  rgdcritstrkpct  rgdhitpct  \
# 0           NaN     NaN       NaN       NaN             NaN        NaN
# 1           NaN     NaN       NaN      37.0             NaN        NaN
# 2           NaN     NaN       NaN      31.0             NaN        NaN
# 3           NaN     NaN       NaN      29.0             NaN        NaN
# 4           NaN     NaN       NaN      58.0             NaN        NaN
#
#    sellprice  shares  sheathtype  slotbak  speed  splcritstrkpct  splpwr  \
# 0      16766     NaN           1       17    3.6             NaN     NaN
# 1      18923     NaN           1       17    3.5             NaN     NaN
# 2      10153     NaN           1       17    2.8             NaN     NaN
# 3       9930     NaN           1       17    3.8             NaN     NaN
# 4      73036     NaN           1       17    3.8             NaN     NaN
#
#     spi  splheal   sta   str  attainable  flags2
# 0   NaN      NaN  14.0  15.0           0    8192
# 1   NaN      NaN   NaN   NaN           0    8192
# 2  12.0      NaN   4.0   NaN           0    8192
# 3   NaN      NaN   8.0  15.0           0    8192
# 4   NaN      NaN  13.0   NaN           0    8192

# %%
rawData2 = pd.read_csv('weaponsupp.csv')
rawData2.head()
# Out:
#    armor  classs commondrop  displayid    dps  flags2     id  level  \
# 0    NaN       2        NaN      22734  35.56    8192   6975     40
# 1    NaN       2        NaN      22221  37.29    8192   7717     42
# 2    NaN       2        NaN       7324  24.64    8192   3853     36
# 3    NaN       2        NaN      22217  28.95    8192   6687     34
# 4    NaN       2        NaN      23904  53.82    8192  12784     63
#
#                     name  reqclass  reqlevel  reqrace  side  slot  slotbak  \
# 0         5Whirlwind Axe       1.0      30.0      NaN   NaN    17       17
# 1               5Ravager       NaN      37.0      NaN   NaN    17       17
# 2  6Moonsteel Broadsword       NaN      31.0      NaN   NaN    17       17
# 3           5Corpsemaker       NaN      29.0      NaN   NaN    17       17
# 4       5Arcanite Reaper       NaN      58.0      NaN   NaN    17       17
#
#    source__001  source__002  sourcemore__bd  sourcemore__dd  sourcemore__c  \
# 0          4.0          NaN             NaN             NaN          -81.0
# 1          2.0          NaN             NaN            -1.0            NaN
# 2          1.0          NaN             NaN             NaN           11.0
# 3          2.0          NaN             NaN            -1.0            NaN
# 4          1.0          NaN             NaN             NaN           11.0
#
#   sourcemore__icon  sourcemore__c2         sourcemore__n  sourcemore__s  \
# 0              NaN             4.0      Whirlwind Weapon            NaN
# 1              NaN             NaN                 Herod            NaN
# 2     inv_sword_25             NaN  Moonsteel Broadsword          164.0
# 3              NaN             NaN      Overlord Ramtusk            NaN
# 4       inv_axe_09             NaN       Arcanite Reaper          164.0
#
#    sourcemore__t  sourcemore__ti  sourcemore__z  speed  subclass  \
# 0            5.0          1792.0            NaN    3.6         1
# 1            1.0          3975.0          796.0    3.5         1
# 2            6.0          3496.0            NaN    2.8         8
# 3            1.0          4420.0          491.0    3.8         1
# 4            6.0         16994.0            NaN    3.8         1
#
#    firstseenpatch  popularity  contentPhase
# 0               0       15979             1
# 1               0       11434             1
# 2               0        9882             1
# 3               0        8119             1
# 4               0        7806             1

# %%
weaponData1 = pd.DataFrame(rawData1[['name', 'quality', 'dps', 'speed', 'rgdcritstrkpct','rgdhitpct', 'atkpwr', 'str', 'agi']])
weaponData1.head()

weaponData2 = pd.DataFrame(rawData2[['level', 'reqclass', 'reqlevel', 'subclass']])
weaponData2.head()
# 'level', 'reqclass', 'reqlevel'

weaponData = weaponData1.join(weaponData2)
weaponData.rename(columns={'rgdcritstrkpct':'critstrkpct', 'rgdhitpct':'hitpct', 'subclass':'type'}, inplace=True)
weaponData.head(100)
# Out:
#                                        name  quality    dps  speed  \
# 0                             Whirlwind Axe        3  35.56    3.6
# 1                                   Ravager        3  37.29    3.5
# 2                      Moonsteel Broadsword        2  24.64    2.8
# 3                               Corpsemaker        3  28.95    3.8
# 4                           Arcanite Reaper        3  53.82    3.8
# 5                Sulfuras, Hand of Ragnaros        5  80.41    3.7
# 6                     Manual Crowd Pummeler        3  29.00    2.0
# 7                            Verigan's Fist        3  25.63    3.2
# 8                     Sul'thraze the Lasher        4  52.12    2.6
# 9                                 Bonebiter        3  38.82    3.4
# 10                                Nightfall        4  67.00    3.5
# 11                          Whirlwind Sword        3  35.52    2.9
# 12                            Fiery War Axe        4  40.34    2.9
# 13                    Blackblade of Shahram        4  59.43    3.5
# 14                         Pendulum of Doom        3  38.88    4.0
# 15                          Sulfuron Hammer        4  63.65    3.7
# 16                     Kang the Decapitator        4  47.36    3.6
# 17                    Executioner's Cleaver        3  41.84    3.8
# 18                     Obsidian Edged Blade        4  64.71    3.4
# 19                      Whirlwind Warhammer        3  35.74    3.4
# 20                               Nightblade        4  43.39    2.8
# 21                                  Archeus        2  23.94    3.3
# 22                           Cobalt Crusher        3  28.91    3.2
# 23                            Searing Blade        3  19.60    2.5
# 24                     Corrupted Ashbringer        4  90.00    3.6
# 25                      Strike of the Hydra        3  25.61    3.3
# 26                              Stoneslayer        3  42.69    3.9
# 27                        Bonereaver's Edge        4  75.88    3.4
# 28                                Warmonger        3  45.00    3.0
# 29                          The Rockpounder        3  42.70    3.7
# 30                     Dark Iron Pulverizer        3  47.43    3.7
# 31                                  Destiny        4  53.85    2.6
# 32                         Mograine's Might        3  38.93    2.8
# 33                         Ice Barbed Spear        3  53.89    3.6
# 34                             Brain Hacker        4  56.67    2.1
# 35                    Dreadforge Retaliator        3  50.54    3.7
# 36                      Blade of the Titans        3  42.58    3.3
# 37                          Burning War Axe        3  27.73    3.3
# 38             Runeblade of Baron Rivendare        4  59.44    3.6
# 39                               X'caliboar        3  37.27    3.3
# 40                           Viscous Hammer        3  30.17    2.9
# 41              Princess Theradras' Scepter        3  46.47    3.4
# 42                         Impervious Giant        3  48.89    2.7
# 43  Ashkandi, Greatsword of the Brotherhood        4  81.86    3.5
# 44                    The Unstoppable Force        4  61.45    3.8
# 45                            Gatorbite Axe        3  45.78    3.2
# 46              Lord Alexander's Battle Axe        3  48.13    3.2
# 47                             Bloodspiller        3  26.67    2.7
# 48                            Spinal Reaper        4  74.71    3.4
# 49                        Might of Menethil        4  95.26    3.8
# 50                     The Blackrock Slicer        3  49.75    4.0
# 51                          Chromatic Sword        2  34.72    3.6
# 52                         Archaic Defender        3  31.29    3.1
# 53                    Smite's Mighty Hammer        3  19.71    3.5
# 54                    Ta'Kierthan Songblade        3  48.94    3.3
# 55                         Grimlok's Charge        3  40.93    2.7
# 56                              Morbid Dawn        3  30.17    2.9
# 57                         Taran Icebreaker        4  49.57    2.3
# 58                   Thermaplugg's Left Arm        3  32.59    2.7
# 59                                 Killmaim        3  21.72    3.2
# 60                               Demonshear        3  53.82    3.8
# 61                          Diabolic Skiver        3  42.76    2.9
# 62                             Shadowstrike        4  59.35    3.1
# 63               Will of the Mountain Giant        2  39.46    2.8
# 64                      Truesilver Champion        3  45.00    3.0
# 65                    Dark Edge of Insanity        4  86.57    3.5
# 66                           Prospector Axe        3  17.50    2.4
# 67                  Warblade of Caer Darrow        3  53.94    3.3
# 68                             The Pacifier        3  32.50    4.0
# 69                                Manslayer        3  34.53    3.2
# 70                              Earthshaker        4  62.57    3.5
# 71                                Witchfury        3  38.93    2.8
# 72                            Fist of Omokk        3  51.36    3.3
# 73                          Unyielding Maul        3  52.97    3.2
# 74                        Arcanite Champion        3  53.83    3.0
# 75                                  Bullova        1  22.37    3.8
# 76                    Hellslayer Battle Axe        3  35.52    2.9
# 77                             Boahn's Fang        3  17.60    2.5
# 78                     Hammer of the Titans        3  53.82    3.8
# 79                 Grand Marshal's Claymore        4  77.37    3.8
# 80                           Doomulus Prime        3  55.66    3.8
# 81                    Gizmotron Megachopper        3  23.91    3.2
# 82                        Lightforged Blade        3  44.85    3.3
# 83                          Rock Pulverizer        2  31.22    3.7
# 84                          Gargoyle's Bite        3  18.97    2.9
# 85                             Silver Spade        2  30.14    3.7
# 86               Will of the Mountain Giant        2  39.46    2.8
# 87                           Blade of Hanna        4  60.24    2.1
# 88                               Peacemaker        3  50.44    3.4
# 89                      Dense Triangle Mace        3  22.92    2.4
# 90                             The Shoveler        3  32.50    3.4
# 91                          Runic Darkblade        2  21.67    3.3
# 92                      Executioner's Sword        2  15.88    3.4
# 93                        Ancient War Sword        2  21.67    3.3
# 94                         Orcish War Sword        1  18.23    3.1
# 95                                Pitchfork        0  10.00    3.7
# 96                               Slaghammer        3  23.75    2.8
# 97                             Night Reaver        3  19.70    3.3
# 98                                Blackfury        4  62.62    2.1
# 99                              Grim Reaper        3  35.65    3.1
#
#     critstrkpct  hitpct  atkpwr   str   agi  level  reqclass  reqlevel  type
# 0           NaN     NaN     NaN  15.0   NaN     40       1.0      30.0     1
# 1           NaN     NaN     NaN   NaN   NaN     42       NaN      37.0     1
# 2           NaN     NaN     NaN   NaN   NaN     36       NaN      31.0     8
# 3           NaN     NaN     NaN  15.0   NaN     34       NaN      29.0     1
# 4           NaN     NaN    62.0   NaN   NaN     63       NaN      58.0     1
# 5           NaN     NaN     NaN  12.0   NaN     80       NaN      60.0     5
# 6           NaN     NaN     NaN  16.0   5.0     34       NaN      29.0     5
# 7           NaN     NaN     NaN   NaN   NaN     31       2.0      20.0     5
# 8           NaN     NaN     NaN   NaN   NaN     55       NaN      50.0     8
# 9           NaN     NaN     NaN  20.0   NaN     44       NaN      34.0     1
# 10          NaN     NaN     NaN   NaN   NaN     70       NaN      60.0     1
# 11          NaN     NaN     NaN  15.0   NaN     40       1.0      30.0     8
# 12          NaN     NaN     NaN   NaN   NaN     40       NaN      35.0     1
# 13          NaN     NaN     NaN   NaN   NaN     63       NaN      58.0     8
# 14          NaN     NaN     NaN   NaN   NaN     44       NaN      39.0     1
# 15          NaN     NaN     NaN   NaN   NaN     67       NaN      60.0     5
# 16          NaN     NaN     NaN   NaN   NaN     49       NaN      44.0     1
# 17          NaN     1.0     NaN  23.0   NaN     48       NaN      43.0     1
# 18          NaN     NaN     NaN  42.0   NaN     68       NaN      60.0     8
# 19          NaN     NaN     NaN  15.0   NaN     40       1.0      30.0     5
# 20          NaN     NaN     NaN   NaN   NaN     44       NaN      39.0     8
# 21          NaN     NaN     NaN   NaN   NaN     35       NaN      28.0     8
# 22          NaN     NaN     NaN   NaN   NaN     34       NaN      29.0     5
# 23          NaN     NaN     NaN   NaN   NaN     23       NaN      18.0     8
# 24          2.0     1.0     NaN   NaN   NaN     86       NaN      60.0     8
# 25          NaN     NaN     NaN   NaN   NaN     31       NaN      26.0     8
# 26          NaN     NaN     NaN   NaN   NaN     49       NaN      44.0     8
# 27          1.0     NaN     NaN   NaN   NaN     77       NaN      60.0     8
# 28          NaN     3.0     NaN   3.0   NaN     52       NaN      47.0     8
# 29          2.0     NaN     NaN   5.0   NaN     49       NaN      44.0     5
# 30          NaN     NaN     NaN   NaN   NaN     55       NaN      50.0     5
# 31          NaN     NaN     NaN   NaN   NaN     57       NaN      52.0     8
# 32          NaN     NaN     NaN   NaN   NaN     44       NaN      39.0     5
# 33          NaN     NaN     NaN  13.0  21.0     63       NaN      51.0     6
# 34          NaN     NaN     NaN   NaN   NaN     60       NaN      55.0     1
# 35          1.0     NaN    30.0   NaN   NaN     59       NaN      54.0     1
# 36          NaN     NaN     NaN  10.0   NaN     49       NaN      44.0     8
# 37          NaN     NaN     NaN   NaN   NaN     33       NaN      28.0     1
# 38          NaN     NaN     NaN   NaN   NaN     63       NaN      58.0     8
# 39          NaN     NaN     NaN  20.0   NaN     42       NaN      35.0     8
# 40          NaN     NaN    34.0   3.0   NaN     35       NaN      30.0     5
# 41          NaN     NaN     NaN   NaN   NaN     54       NaN      49.0     5
# 42          2.0     1.0     NaN   NaN   NaN     57       NaN      52.0     5
# 43          NaN     NaN    86.0   NaN   NaN     81       NaN      60.0     8
# 44          2.0     NaN     NaN  19.0   NaN     65       NaN      60.0     5
# 45          NaN     NaN     NaN   NaN   NaN     53       NaN      48.0     1
# 46          NaN     NaN     NaN  16.0  17.0     56       NaN      51.0     1
# 47          NaN     NaN     NaN   NaN   NaN     32       NaN      27.0     1
# 48          NaN     NaN    34.0   NaN   NaN     76       NaN      60.0     1
# 49          2.0     NaN     NaN  20.0   NaN     89       NaN      60.0     5
# 50          NaN     NaN     NaN   NaN   NaN     58       NaN      53.0     1
# 51          NaN     NaN     NaN   NaN   NaN     45       NaN      40.0     8
# 52          NaN     NaN     NaN   NaN   NaN     36       NaN      31.0     8
# 53          NaN     NaN     NaN  11.0   4.0     23       NaN      18.0     5
# 54          NaN     NaN     NaN   NaN   NaN     57       NaN      52.0     8
# 55          NaN     NaN     NaN  10.0  15.0     47       NaN      42.0     6
# 56          NaN     NaN     NaN  10.0   NaN     35       NaN      30.0     8
# 57          NaN     NaN     NaN   NaN   NaN     52       NaN      47.0     5
# 58          NaN     NaN     NaN  18.0   NaN     37       NaN      32.0     1
# 59          NaN     NaN     NaN   NaN   NaN     26       NaN      21.0     1
# 60          NaN     NaN     NaN   NaN   NaN     63       NaN      58.0     8
# 61          NaN     NaN     NaN   NaN   NaN     49       NaN      44.0     6
# 62          NaN     NaN     NaN   NaN   NaN     63       NaN      58.0     6
# 63          NaN     NaN     NaN  15.0   NaN     51       NaN      40.0     1
# 64          NaN     NaN     NaN   NaN   NaN     52       NaN      47.0     8
# 65          NaN     NaN     NaN  35.0  19.0     84       NaN      60.0     1
# 66          NaN     NaN     NaN   7.0   NaN     20       NaN      15.0     1
# 67          NaN     NaN     NaN   NaN   NaN     63       NaN      57.0     8
# 68          NaN     NaN     NaN  18.0   NaN     37       NaN      32.0     5
# 69          NaN     NaN    38.0   NaN   NaN     39       NaN      34.0     1
# 70          NaN     NaN    22.0   NaN   NaN     66       NaN      60.0     5
# 71          NaN     NaN     NaN   NaN   NaN     44       NaN      39.0     8
# 72          NaN     NaN     NaN  29.0   NaN     60       NaN      55.0     5
# 73          NaN     NaN     NaN   NaN   NaN     62       NaN      57.0     5
# 74          NaN     NaN     NaN   NaN   NaN     63       NaN      58.0     8
# 75          NaN     NaN     NaN   NaN   NaN     35       NaN      30.0     1
# 76          NaN     NaN     NaN   NaN   NaN     40       NaN      35.0     1
# 77          NaN     NaN     NaN   9.0   NaN     20       NaN      15.0     1
# 78          NaN     NaN     NaN  15.0   NaN     63       NaN      58.0     5
# 79          1.0     NaN     NaN  26.0   NaN     78       NaN      60.0     8
# 80          NaN     1.0     NaN  22.0   NaN     65       NaN      60.0     5
# 81          NaN     NaN     NaN  14.0   5.0     29       NaN      24.0     8
# 82          NaN     NaN     NaN   9.0   NaN     52       NaN      47.0     8
# 83          NaN     NaN    34.0   NaN   NaN     42       NaN      30.0     5
# 84          NaN     NaN     NaN  10.0   NaN     22       NaN      20.0     6
# 85          NaN     NaN     NaN   NaN   NaN     41       NaN      30.0     5
# 86          NaN     NaN     NaN  15.0   NaN     51       NaN      46.0     1
# 87          NaN     NaN     NaN  11.0  11.0     64       NaN      59.0     8
# 88          1.0     NaN    56.0   NaN   NaN     59       NaN      54.0     6
# 89          NaN     NaN     NaN  10.0   NaN     28       NaN      23.0     5
# 90          NaN     NaN    20.0   NaN   NaN     37       1.0      32.0     5
# 91          NaN     NaN     NaN   NaN   NaN     32       NaN      19.0     8
# 92          NaN     NaN     NaN   8.0   NaN     24       NaN      19.0     8
# 93          NaN     NaN     NaN   9.0   NaN     32       NaN      23.0     8
# 94          NaN     NaN     NaN   NaN   NaN     29       NaN      25.0     8
# 95          NaN     NaN     NaN   NaN   NaN     25       NaN      20.0     6
# 96          NaN     NaN     NaN  11.0   NaN     29       NaN      24.0     5
# 97          NaN     NaN     NaN   NaN   NaN     23       NaN      18.0     1
# 98          1.0     NaN     NaN  35.0   NaN     66       NaN      60.0     6
# 99          NaN     NaN     NaN   NaN   NaN     40       NaN      35.0     6

# %%
# weaponData = pd.DataFrame(rawData[['type', 'name', 'popularity', 'quality', 'level', 'reqclass', 'reqlevel','dps', 'speed', 'critstrkpct','hitpct', 'atkpwr', 'str', 'agi']])

# %%
weaponData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 13 columns):
# name           418 non-null object
# quality        418 non-null int64
# dps            418 non-null float64
# speed          418 non-null float64
# critstrkpct    28 non-null float64
# hitpct         8 non-null float64
# atkpwr         16 non-null float64
# str            133 non-null float64
# agi            36 non-null float64
# level          418 non-null int64
# reqclass       5 non-null float64
# reqlevel       404 non-null float64
# type           418 non-null int64
# dtypes: float64(9), int64(3), object(1)
# memory usage: 42.6+ KB

# %%
weaponData = weaponData.fillna(0)
weaponData.head()
# Out:
#                    name  quality    dps  speed  critstrkpct  hitpct  atkpwr  \
# 0         Whirlwind Axe        3  35.56    3.6          0.0     0.0     0.0
# 1               Ravager        3  37.29    3.5          0.0     0.0     0.0
# 2  Moonsteel Broadsword        2  24.64    2.8          0.0     0.0     0.0
# 3           Corpsemaker        3  28.95    3.8          0.0     0.0     0.0
# 4       Arcanite Reaper        3  53.82    3.8          0.0     0.0    62.0
#
#     str  agi  level  reqclass  reqlevel  type
# 0  15.0  0.0     40       1.0      30.0     1
# 1   0.0  0.0     42       0.0      37.0     1
# 2   0.0  0.0     36       0.0      31.0     8
# 3  15.0  0.0     34       0.0      29.0     1
# 4   0.0  0.0     63       0.0      58.0     1

# %%
weaponData[['reqclass','reqlevel']] = weaponData[['reqclass','reqlevel']].astype(int)
weaponData.head()
# Out:
#                    name  quality    dps  speed  critstrkpct  hitpct  atkpwr  \
# 0         Whirlwind Axe        3  35.56    3.6          0.0     0.0     0.0
# 1               Ravager        3  37.29    3.5          0.0     0.0     0.0
# 2  Moonsteel Broadsword        2  24.64    2.8          0.0     0.0     0.0
# 3           Corpsemaker        3  28.95    3.8          0.0     0.0     0.0
# 4       Arcanite Reaper        3  53.82    3.8          0.0     0.0    62.0
#
#     str  agi  level  reqclass  reqlevel  type
# 0  15.0  0.0     40         1        30     1
# 1   0.0  0.0     42         0        37     1
# 2   0.0  0.0     36         0        31     8
# 3  15.0  0.0     34         0        29     1
# 4   0.0  0.0     63         0        58     1

# %%
weaponData['type'] = weaponData['type'].map({1:'Two-handed Axe', 5:'Mace', 6:'Polearm', 8:'Two-handed Sword'})
weaponData.head()
# Out:
#                    name  quality    dps  speed  critstrkpct  hitpct  atkpwr  \
# 0         Whirlwind Axe        3  35.56    3.6          0.0     0.0     0.0
# 1               Ravager        3  37.29    3.5          0.0     0.0     0.0
# 2  Moonsteel Broadsword        2  24.64    2.8          0.0     0.0     0.0
# 3           Corpsemaker        3  28.95    3.8          0.0     0.0     0.0
# 4       Arcanite Reaper        3  53.82    3.8          0.0     0.0    62.0
#
#     str  agi  level  reqclass  reqlevel              type
# 0  15.0  0.0     40         1        30    Two-handed Axe
# 1   0.0  0.0     42         0        37    Two-handed Axe
# 2   0.0  0.0     36         0        31  Two-handed Sword
# 3  15.0  0.0     34         0        29    Two-handed Axe
# 4   0.0  0.0     63         0        58    Two-handed Axe

# %%
dph = weaponData.speed * weaponData.dps
weaponData.insert(loc=8, column='dph', value=dph)
weaponData.head()
# Out:
#                    name  quality    dps  speed  critstrkpct  hitpct  atkpwr  \
# 0         Whirlwind Axe        3  35.56    3.6          0.0     0.0     0.0
# 1               Ravager        3  37.29    3.5          0.0     0.0     0.0
# 2  Moonsteel Broadsword        2  24.64    2.8          0.0     0.0     0.0
# 3           Corpsemaker        3  28.95    3.8          0.0     0.0     0.0
# 4       Arcanite Reaper        3  53.82    3.8          0.0     0.0    62.0
#
#     str      dph  agi  level  reqclass  reqlevel              type
# 0  15.0  128.016  0.0     40         1        30    Two-handed Axe
# 1   0.0  130.515  0.0     42         0        37    Two-handed Axe
# 2   0.0   68.992  0.0     36         0        31  Two-handed Sword
# 3  15.0  110.010  0.0     34         0        29    Two-handed Axe
# 4   0.0  204.516  0.0     63         0        58    Two-handed Axe

# %%
weaponData = weaponData.drop(weaponData[weaponData['reqclass']>1].index)

for index, row in weaponData.iterrows():
    if row['reqlevel'] == 0:
        if row['level'] <= 5:
            weaponData.at[index,'reqlevel'] = 1
        elif row['level'] >= 66:
            weaponData.at[index,'reqlevel'] = 60
        else:
            tmp = row['level'] - 5
            weaponData.at[index,'reqlevel'] = tmp

# %%
# Types in the Dataset
print("Number of Types :", len(weaponData["type"].unique()))

# Two-handed weapons in each type
print(weaponData["type"].value_counts())
sb.catplot(y = "type", data = weaponData, kind = "count", height=4, aspect=2)
# Out:
# Number of Types : 4
# Mace                128
# Two-handed Sword    126
# Two-handed Axe      119
# Polearm              44
# Name: type, dtype: int64

# %%
# fig, axis = plt.subplots(2, 2, figsize(2, 2))
# colors = ["r", "g", "b", "m"]
fig, axis = plt.subplots(1, 2, figsize=(18, 6))
uniqueVals = weaponData["type"].unique()
types = [weaponData[weaponData["type"]== val] for val in uniqueVals]

for i, t in enumerate(['dps', 'dph']):
    for idx, weaponType in enumerate(types):
        sb.distplot(weaponType[t], ax=axis[i % 2], hist=False, kde_kws=dict(cumulative=True), label=uniqueVals[idx])
        

weaponDataByLevel = weaponData.sort_values('reqlevel')

fig, axis = plt.subplots(1, 2, figsize=(18, 6))
uniqueVals = weaponDataByLevel["type"].unique()
types = [weaponDataByLevel[weaponDataByLevel["type"]== val] for val in uniqueVals]

for i, t in enumerate(['dps', 'dph']):
    for idx, weaponType in enumerate(types):
        sb.lineplot(x=weaponType['reqlevel'], y=weaponType[t], data=weaponType, ax=axis[i % 2], label=uniqueVals[idx])

# %%
        
#plt.show(block=True)

# %%
# rareWeaponData = weaponData[weaponData["quality"] == 3]
rareWeaponData = weaponData.query('quality== ["3", "4"]')
rareWeaponData.info()

fig, axis = plt.subplots(1, 2, figsize=(18, 6))
uniqueVals = rareWeaponData["type"].unique()
types = [rareWeaponData[rareWeaponData["type"]== val] for val in uniqueVals]

for i, t in enumerate(['dps', 'dph']):
    for idx, WeaponData in enumerate(types):
        sb.distplot(WeaponData[t], ax=axis[i % 2], hist=False, kde_kws=dict(cumulative=True), label=uniqueVals[idx])

rareWeaponDataByLevel = rareWeaponData.sort_values('reqlevel')
rareWeaponDataByLevel.info()
fig, axis = plt.subplots(1, 2, figsize=(18, 6))
uniqueVals = rareWeaponDataByLevel["type"].unique()
types = [rareWeaponDataByLevel[rareWeaponDataByLevel["type"]== val] for val in uniqueVals]

for i, t in enumerate(['dps', 'dph']):
    for idx, weaponType in enumerate(types):
        sb.lineplot(x=weaponType['reqlevel'], y=weaponType[t], data=weaponType, ax=axis[i % 2], label=uniqueVals[idx],alpha=1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 190 entries, 0 to 363
# Data columns (total 14 columns):
# name           190 non-null object
# quality        190 non-null int64
# dps            190 non-null float64
# speed          190 non-null float64
# critstrkpct    190 non-null float64
# hitpct         190 non-null float64
# atkpwr         190 non-null float64
# str            190 non-null float64
# dph            190 non-null float64
# agi            190 non-null float64
# level          190 non-null int64
# reqclass       190 non-null int64
# reqlevel       190 non-null int64
# type           190 non-null object
# dtypes: float64(8), int64(4), object(2)
# memory usage: 22.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 190 entries, 66 to 363
# Data columns (total 14 columns):
# name           190 non-null object
# quality        190 non-null int64
# dps            190 non-null float64
# speed          190 non-null float64
# critstrkpct    190 non-null float64
# hitpct         190 non-null float64
# atkpwr         190 non-null float64
# str            190 non-null float64
# dph            190 non-null float64
# agi            190 non-null float64
# level          190 non-null int64
# reqclass       190 non-null int64
# reqlevel       190 non-null int64
# type           190 non-null object
# dtypes: float64(8), int64(4), object(2)
# memory usage: 22.3+ KB

# %%
X = rareWeaponData[['reqlevel']]
linreg = LinearRegression()
ranreg = RANSACRegressor(LinearRegression(), max_trials = 1000, stop_probability = 0.9999, residual_threshold=1)
baseSpeed = 3.6
f, axes = plt.subplots(2, 1, figsize=(16, 8))

Y = rareWeaponData[['dps']]
linreg.fit(X, Y)
ranreg.fit(X, Y)

reglineX = X
reglineY = linreg.intercept_ + linreg.coef_ * X
reglineYRansac = ranreg.estimator_.intercept_ + ranreg.estimator_.coef_ * X

axes[0].scatter(X, Y)
axes[0].plot(reglineX, reglineY, 'r-', linewidth = 3)
axes[0].plot(reglineX, reglineYRansac, 'g-', linewidth = 3)

reglinePredFromDps = baseSpeed * reglineYRansac

Y = rareWeaponData[['dph']]
axes[1].scatter(X, Y)
axes[1].plot(reglineX, reglinePredFromDps, 'y-', linewidth = 3)

# %%
keys = list(range(1,61))
values = (ranreg.estimator_.intercept_ + ranreg.estimator_.coef_[0] * keys) * baseSpeed
Benchmark = dict(zip(keys, values))

rareWeaponData.loc[:,'baseDPH'] = rareWeaponData.loc[:,'reqlevel'].map(Benchmark)
rareWeaponData.loc[:, 'diffDPH'] = rareWeaponData.loc[:, 'dph'] - rareWeaponData.loc[:,'baseDPH']
rareWeaponData.loc[:, 'levelsup'] = ((rareWeaponData.loc[:, 'diffDPH'] / baseSpeed))/ ranreg.estimator_.coef_[0]

sortedWeaponData = rareWeaponData.sort_values(['reqlevel', 'levelsup'], ascending=[True, False])
sortedWeaponData.to_csv('result.csv')
sortedWeaponData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 190 entries, 77 to 98
# Data columns (total 17 columns):
# name           190 non-null object
# quality        190 non-null int64
# dps            190 non-null float64
# speed          190 non-null float64
# critstrkpct    190 non-null float64
# hitpct         190 non-null float64
# atkpwr         190 non-null float64
# str            190 non-null float64
# dph            190 non-null float64
# agi            190 non-null float64
# level          190 non-null int64
# reqclass       190 non-null int64
# reqlevel       190 non-null int64
# type           190 non-null object
# baseDPH        190 non-null float64
# diffDPH        190 non-null float64
# levelsup       190 non-null float64
# dtypes: float64(11), int64(4), object(2)
# memory usage: 26.7+ KB
# /home/su/anaconda3/envs/wow/lib/python3.7/site-packages/pandas/core/indexing.py:376: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/su/anaconda3/envs/wow/lib/python3.7/site-packages/pandas/core/indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
# 
sortedWeaponData.head()
mask1 = sortedWeaponData.loc[:,'levelsup'] > 0
mask2 = sortedWeaponData.loc[:,'reqlevel'] < 60
mask = mask1 & mask2
sortedWeaponData = sortedWeaponData[mask]
sortedWeaponData.head()

occur = sortedWeaponData.groupby('reqlevel').cumcount()
sortedWeaponData.insert(loc=16, column='occur', value=occur)
sortedWeaponData.head()
#
# Out:
#                    name  quality    dps  speed  critstrkpct  hitpct  atkpwr  \
# 3           Corpsemaker        3  28.95    3.8          0.0     0.0     0.0
# 0         Whirlwind Axe        3  35.56    3.6          0.0     0.0     0.0
# 19  Whirlwind Warhammer        3  35.74    3.4          0.0     0.0     0.0
# 68         The Pacifier        3  32.50    4.0          0.0     0.0     0.0
# 9             Bonebiter        3  38.82    3.4          0.0     0.0     0.0
#
#      str      dph  agi  level  reqclass  reqlevel            type     baseDPH  \
# 3   15.0  110.010  0.0     34         0        29  Two-handed Axe  105.655424
# 0   15.0  128.016  0.0     40         1        30  Two-handed Axe  108.737847
# 19  15.0  121.516  0.0     40         1        30            Mace  108.737847
# 68  18.0  130.000  0.0     37         0        32            Mace  114.902692
# 9   20.0  131.988  0.0     44         0        34  Two-handed Axe  121.067537
#
#       diffDPH  occur  levelsup
# 3    4.354576      0  1.412712
# 0   19.278153      0  6.254221
# 19  12.778153      1  4.145490
# 68  15.097308      0  4.897871
# 9   10.920463      0  3.542818

# %%
resultByLevelsup = pd.pivot_table(sortedWeaponData, index = ['reqlevel', 'occur'], values="levelsup")
resultByName = pd.pivot_table(sortedWeaponData, index = ['reqlevel', 'occur'], values="name",aggfunc='first')

result = pd.concat([resultByLevelsup, resultByName], axis=1).reset_index()
result.head(100)

r = len(result['reqlevel'].unique())
n = len(result.index)


rows = result['reqlevel']
widths = result['levelsup']
labels = result['name']
row_counts = np.arange(0, n)
left = np.zeros(r,)
idx = np.arange(0,n)
pointer = 0
patch_handles = []

for (level, i) in zip(result['reqlevel'], idx):
    if i>0:
        if result['reqlevel'].loc[i]!= result['reqlevel'].loc[i-1]:
            pointer+=1
    idx[i] = pointer


fig, ax = plt.subplots(1, 1, figsize=(20, 16))
for (r, w, l, i, j) in zip(rows, widths, labels, idx, row_counts):
    dif = ('%.3f' % w)
    label = (str(j) + '    ' + l + '    ' + str(dif))
    patch_handles.append(ax.barh(r, w, align='center', left=left[i], label=label))

    left[i] += w
    patch = patch_handles[-1][0] 
    bl = patch.get_xy()
    x = 0.5*patch.get_width() + bl[0]
    y = 0.5*patch.get_height() + bl[1]
    ax.text(x, y, "%s" % (j), ha='center',va='center',size = 20)
    
y_pos = result['reqlevel'].unique()
ax.set_yticks(y_pos)
ax.tick_params(axis='y', labelsize=20)
ax.legend(prop={'size': 20})
ax.set_ylabel('Character Level', fontsize=25)
ax.set_title('Top Two-handed Weapons by Damage Per Hit', fontsize=25)
# Out:
# Text(0.5, 1.0, 'Two-handed Weapon Ranking by Damage Per Hit')
